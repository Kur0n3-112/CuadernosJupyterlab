# %% [markdown]
# # 01. Hello, Python
# ## 01.1. Introduction
# This is the first Python program

# %%
spam_amount = 0
print(spam_amount)

# Ordering Spam, egg, Spam, Spam, bacon and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# 0
# But I don't want ANY spam!
# Spam Spam Spam Spam

# %% [markdown]
# ### 01.1.1. Asignacion de variables

# %%
spam_amount = 0
print(spam_amount)
# Out:
# 0

# %% [markdown]
# ### 01.1.2. Numeros y aritmetica en Python

# %%
spam_amount = 0 
hello = 'hello, world!'
print(type(spam_amount), type(hello))
# Out:
# <class 'int'> <class 'str'>

# %%
print(type(14.24))
# Out:
# <class 'float'>

# %% [markdown]
# #### 01.1.2.1. Tipos de operadores aritmeticos
# |Operador|Nombre|Descripcion|
# |----|----|----|
# |a + b|Adicion|Suma de a y b|
# |a - b|Substraer|Resta de a y b|
# |a * b|Multiplicacion| Producto de a y b|
# |a / b|Division verdadera| Cociente de a y b|
# |a // b| Division de resto|Cociente de a y b, sin fracciones|
# |a % b | Modulo| Resto tras la division de a y b|
# |a ** b| Exponenciacion| a elevado a b veces|
# | -a | Negacion| La negacion de a |
#
# ### 01.1.3. Funciones nativas para trabajar con numeros en Python

# %%
print(min(1, 2, 3)) #Devuelve el valor minimo del conjunto de numeros que se le pasen a la funcion como argumentos
print(max(1, 2, 3)) #Devuelve el valor maximo del conjunto de numeros que se le pasen a la funcion como argumentos
print(abs(32)) #Devuelve el valor absoluto del argumento
print(abs(-32)) #Devuelve el valor absoluto del argumento
# Out:
# 1
# 3
# 32
# 32

# %% [markdown]
# ### 01.1.4. Convertir variables o numeros a otros tipos en Python

# %%
print(float(10))
print(int(3.33))
print(int('807') + 1)
# Out:
# 10.0
# 3
# 808
