# %% [markdown]
# # **02. Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## **02.1. Introduccion**
# Para importar la libreria pandas `import pandas as pd`

# %% [markdown]
# ### **02.1.1. Creacion de datos**

# %% [markdown]
# #### **02.1.1.1. DataFrame**
# Son tablas que contienen entradas individuales las cuales cada celda tiene un valor, y cada fila (o registro) es una entrada, y tiene columnas, es como una tabla en SQL.

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# #### **02.1.1.2. Series**
# Son una secuencia de valores, si un DataFrame es una tabla, una Serie es una lista, de echo se crean con nada mas ni nada menos que una lista.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ### **02.1.2. Leer archivos de datos**
# Pandas permite leer archivos .csv para crear DataFrames y Series.

# %% [markdown]
# - `pd.read_csv()`: permite leer un archivo para interpretarlo con pandas.
# - `shape`: permite ver el tamaño total del contenido del archivo csv.

# %%
wine_reviews = pd.read_csv("./archivosDeDatos/winemag-data-130k-v2.csv")
wine_reviews.shape
# Out:
# (119988, 15)

# %% [markdown]
# - `head()`: permite ver las cinco primeras filas del archivo csv.

# %%
wine_reviews.head()
# Out:
#        id  country                                        description  \
# 0   94355  Austria  "Chremisa," the ancient name of Krems, is comm...
# 1  126883       US  $10 for this very drinkable Cab? That's crazy....
# 2  119493       US  $14 is a pretty good price for a Chardonnay th...
# 3  126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 4  119752    Spain  ). Light and lemony on the nose. The palate ha...
#
#                      designation  points  price          province  \
# 0  Edition Chremisa Sandgrube 13      85   24.0  Niederösterreich
# 1                            NaN      87   10.0        California
# 2                       Whiplash      86   14.0        California
# 3                  Finca Resalso      86   15.0    Northern Spain
# 4                            NaN      87   17.0           Galicia
#
#            region_1          region_2        taster_name  \
# 0               NaN               NaN         Roger Voss
# ...

# %% [markdown]
#  - `read_csv("",index_col=NUMERO):` permite leer un archivo, pero reinterpreta la primera fila que era la del numero de fila.

# %%
wine_reviews = pd.read_csv("./archivosDeDatos/winemag-data-130k-v2.csv", index_col=0)
wine_reviews.head()
# Out:
#         country                                        description  \
# id
# 94355   Austria  "Chremisa," the ancient name of Krems, is comm...
# 126883       US  $10 for this very drinkable Cab? That's crazy....
# 119493       US  $14 is a pretty good price for a Chardonnay th...
# 126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 119752    Spain  ). Light and lemony on the nose. The palate ha...
#
#                           designation  points  price          province  \
# id
# 94355   Edition Chremisa Sandgrube 13      85   24.0  Niederösterreich
# 126883                            NaN      87   10.0        California
# 119493                       Whiplash      86   14.0        California
# 126909                  Finca Resalso      86   15.0    Northern Spain
# 119752                            NaN      87   17.0           Galicia
#
#                 region_1          region_2        taster_name  \
# id
# ...

# %% [markdown]
# ## **02.2. Indexacion, Seleccion y Asignacion**

# %% [markdown]
# ### **02.2.1. Accesos nativos (indexacion en Python)**
# Metodos de acceso a datos que estan integrados en el nucleo de Python, no son tan utiles como los de Pandas pero son mas rapidos en algun aspecto en concreto.
#
# > La primera celda se ejecuta el codigo **sin** la columna del indice, y la segunda **con** la columna del indice.

# %%
reviews = pd.read_csv("./archivosDeDatos/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews = pd.read_csv("./archivosDeDatos/winemag-data-130k-v2.csv")

# %%
reviews.country
# Out:
# 0         Austria
# 1              US
# 2              US
# 3           Spain
# 4           Spain
#            ...
# 119983      Italy
# 119984      Italy
# 119985      Italy
# 119986         US
# 119987    Austria
# Name: country, Length: 119988, dtype: object

# %% [markdown]
# - `dataframe['VALOR']`: devuelve solo una columna de datos.

# %%
reviews['country']
# Out:
# id
# 94355     Austria
# 126883         US
# 119493         US
# 126909      Spain
# 119752      Spain
#            ...
# 80210       Italy
# 76487       Italy
# 86953       Italy
# 18824          US
# 88999     Austria
# Name: country, Length: 119988, dtype: object

# %% [markdown]
# - `dataframe['VALOR'][INDICE]`: devuelve solo el valor de la columna seleccionada.

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# #### **02.2.2. Indexacion en pandas**
# `iloc()` es mejor indexando por indices ya que utiliza la libreria estandar de Python.
#
# **NOTA:** Tanto `loc` como `iloc` siguen el orden «primero la fila, luego la columna». Esto es lo contrario de lo que hacemos en Python nativo, donde el orden es «primero la columna, luego la fila».
#
# Esto significa que resulta ligeramente más fácil recuperar filas y ligeramente más difícil recuperar columnas.

# %% [markdown]
# ##### **02.2.2.1. Seleccion basada en indices**
# Recoger datos mediante la posicion que ocupan en la tabla.

# %%
reviews.iloc[0] #selecciona la primera fila
# Out:
# country                                                            Austria
# description              "Chremisa," the ancient name of Krems, is comm...
# designation                                  Edition Chremisa Sandgrube 13
# points                                                                  85
# price                                                                 24.0
# province                                                  Niederösterreich
# region_1                                                               NaN
# region_2                                                               NaN
# taster_name                                                     Roger Voss
# taster_twitter_handle                                           @vossroger
# title                    Winzer Krems 2011 Edition Chremisa Sandgrube 1...
# variety                                                   Grüner Veltliner
# ...

# %%
reviews.iloc[:, 0] #selecciona toda la primera columna
# Out:
# id
# 94355     Austria
# 126883         US
# 119493         US
# 126909      Spain
# 119752      Spain
#            ...
# 80210       Italy
# 76487       Italy
# 86953       Italy
# 18824          US
# 88999     Austria
# Name: country, Length: 119988, dtype: object

# %%
reviews.iloc[:3, 0] # selecciona los tres primeros valores
# Out:
# id
# 94355     Austria
# 126883         US
# 119493         US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 0] #selecciona de la 1 a la 3 por posicion
# Out:
# id
# 126883    US
# 119493    US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0] #seleeciona 3 entradas en concreto
# Out:
# id
# 94355     Austria
# 126883         US
# 119493         US
# Name: country, dtype: object

# %%
reviews.iloc[-5:] #selecciona las ultimas 5 entradas de la tabla
# Out:
#        country                                        description  \
# id
# 80210    Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487    Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953    Italy  Zorzettig's precious Picolit dessert wine deli...
# 18824       US  Zucca has made a fragrant and floral Sangioves...
# 88999  Austria  Zweigelt can do easy-drinking styles but in th...
#
#              designation  points  price            province  \
# id
# 80210           Zonchera      90   48.0            Piedmont
# 76487                NaN      88   70.0              Veneto
# 86953                NaN      90    NaN  Northeastern Italy
# 18824  Sangiovese Rosato      87   18.0          California
# 88999         Heideboden      90   26.0          Burgenland
#
#                          region_1          region_2       taster_name  \
# id
# 80210                      Barolo               NaN               NaN
# ...

# %% [markdown]
# ##### **02.2.2.2. Seleccion basada en etiquetas**
# Seleccionar datos mediante alguna "etiqueta" que tengan, refiriendome a etiqueta como el nombre de una columna o el nombre de un valor de alguna columna.

# %%
reviews.loc[0, 'country'] #seleccion del primer valor que hay en la columna "country"
# Out:
# 'Italy'

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']] #devuelve los valores de estas tres columnas solo
# Out:
#               taster_name taster_twitter_handle  points
# id
# 94355          Roger Voss            @vossroger      85
# 126883     Virginie Boone               @vboone      87
# 119493                NaN                   NaN      86
# 126909  Michael Schachner           @wineschach      86
# 119752  Michael Schachner           @wineschach      87
# ...                   ...                   ...     ...
# 80210                 NaN                   NaN      90
# 76487                 NaN                   NaN      88
# 86953                 NaN                   NaN      90
# 18824      Virginie Boone               @vboone      87
# 88999    Anne Krebiehl MW           @AnneInVino      90
#
# [119988 rows x 3 columns]

# %% [markdown]
# ##### **02.2.2.3. Elegir entre `loc` e `iloc`**
# A la hora de elegir o cambiar entre `loc` e `iloc`, hay un «matiz» que conviene tener en cuenta: ambos métodos utilizan esquemas de indexación ligeramente diferentes.
#
# `iloc` utiliza el esquema de indexación de la biblioteca estándar de Python, en el que se incluye el primer elemento del rango y se excluye el último. Por lo tanto, 0:10 seleccionará las entradas 0, ..., 9. loc, por su parte, indexa de forma inclusiva. Así, 0:10 seleccionará las entradas 0, ..., 10.
#
# ¿A qué se debe este cambio? Recuerda que loc puede indexar cualquier tipo de la biblioteca estándar: cadenas, por ejemplo. Si tenemos un DataFrame con valores de índice Apples, ..., «Potatoes», …, y queremos seleccionar «todas las frutas en orden alfabético entre Apples y Potatoes», resulta mucho más cómodo indexar df.loc[“Apples”:'Potatoes'] que indexar algo como df.loc[“Apples”, “Potatoet”] (la «t» viene después de la «s» en el alfabeto).
#
# Esto resulta especialmente confuso cuando el índice del DataFrame es una simple lista numérica, por ejemplo, 0,...,1000. En este caso, df.iloc[0:1000] devolverá 1000 entradas, mientras que df.loc[0:1000] devolverá 1001. Para obtener 1000 elementos utilizando `loc`, tendrás que bajar un valor y solicitar `df.loc[0:999]`.
#
# Por lo demás, la semántica del uso de `loc` es la misma que la de `iloc`.

# %% [markdown]
# #### **02.2.3. Manipulacion de los indices**
# Ya que los indices son muy importantes, estos se pueden manipular para poder escoger esos datos de mejor manera mas tarde.

# %%
reviews.set_index("title") #cambio de nombre del indice de la primera columna
# Out:
#                                                     country  \
# title
# Winzer Krems 2011 Edition Chremisa Sandgrube 13...  Austria
# Line 39 2009 Cabernet Sauvignon (North Coast)            US
# Jamieson Ranch 2011 Whiplash Chardonnay (Califo...       US
# Emilio Moro 2009 Finca Resalso  (Ribera del Duero)    Spain
# La Caña 2010 Albariño (Rías Baixas)                   Spain
# ...                                                     ...
# Ceretto 2004 Zonchera  (Barolo)                       Italy
# Zonin 2006  Amarone della Valpolicella                Italy
# Zorzettig 2006 Picolit (Colli Orientali del Fri...    Italy
# Zucca 2010 Sangiovese Rosato Rosé (Amador County)        US
# Nittnaus Hans und Christine 2013 Heideboden Zwe...  Austria
#
#                                                                                           description  \
# title
# Winzer Krems 2011 Edition Chremisa Sandgrube 13...  "Chremisa," the ancient name of Krems, is comm...
# ...

# %% [markdown]
# #### **02.2.4. Seleccion condicional**
# Seleccion de datos mediante alguna condicion que representen estos.

# %%
reviews.country == 'Italy' #aparecen con valores booleanos como True los que si son de Italia y False como los que no son de alli
# Out:
# id
# 94355     False
# 126883    False
# 119493    False
# 126909    False
# 119752    False
#           ...
# 80210      True
# 76487      True
# 86953      True
# 18824     False
# 88999     False
# Name: country, Length: 119988, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy'] #interpretacion de los datos del anterior comando
# Out:
#        country                                        description  \
# id
# 115413   Italy  ). Rubiolo is a soft and lush Chianti Classico...
# 23362    Italy  . There's a compact, traditional characteristi...
# 76094    Italy  . This rich and opulent blend of Cabernet Sauv...
# 83416    Italy  100% Cabernet Sauvignon, this opens with aroma...
# 4515     Italy  95   Massolino 2012 Parafada (Barolo). A textb...
# ...        ...                                                ...
# 1349     Italy  Zibibbo is usually presented as a passito dess...
# 70889    Italy  Zisola is a Nero d'Avola that is aged 10 month...
# 80210    Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487    Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953    Italy  Zorzettig's precious Picolit dessert wine deli...
#
#                    designation  points  price            province  \
# id
# 115413                 Rubiolo      88   23.0             Tuscany
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)] #se usa el & para unir dos preguntas
# Out:
#       country                                        description  \
# id
# 23362   Italy  . There's a compact, traditional characteristi...
# 76094   Italy  . This rich and opulent blend of Cabernet Sauv...
# 83416   Italy  100% Cabernet Sauvignon, this opens with aroma...
# 4515    Italy  95   Massolino 2012 Parafada (Barolo). A textb...
# 81278   Italy  A 25th anniversary special selection, this bea...
# ...       ...                                                ...
# 54397   Italy  Zenato is a reliable producer of quality Amaro...
# 59349   Italy  Zenato's rich and powerful Recioto opens with ...
# 70889   Italy  Zisola is a Nero d'Avola that is aged 10 month...
# 80210   Italy  Zonchera is Ceretto's more affordable base Bar...
# 86953   Italy  Zorzettig's precious Picolit dessert wine deli...
#
#                   designation  points  price            province  \
# id
# 23362      Vigneto Bellavista      90  169.0             Tuscany
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)] #se usa el | el cual es el operador logico OR sirve para decir que se cumpla una cosa o la otra
# Out:
#         country                                        description  \
# id
# 115413    Italy  ). Rubiolo is a soft and lush Chianti Classico...
# 29339        US  ). Very good wine from a winery increasingly k...
# 98444        US  ). Vineyard 7&8's Spring Mountain Estate Caber...
# 60042        US  ). You'll want to cellar this young 100% Cab b...
# 62258        US  . A delightfully intriguing “White Burgundy” b...
# ...         ...                                                ...
# 129643       US  Zocker flies under the radar with this Austria...
# 80210     Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487     Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953     Italy  Zorzettig's precious Picolit dessert wine deli...
# 88999   Austria  Zweigelt can do easy-drinking styles but in th...
#
#                     designation  points  price            province  \
# id
# 115413                  Rubiolo      88   23.0             Tuscany
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])] #pandas tiene algun operador logico incluido como `isin()` el cual comprueba si estan incluidos los valores que se le pasan dentro del conjunto de datos (csv)
# Out:
#        country                                        description  \
# id
# 115413   Italy  ). Rubiolo is a soft and lush Chianti Classico...
# 101344  France  . Recent vintages have left Bordeaux with an a...
# 23362    Italy  . There's a compact, traditional characteristi...
# 76094    Italy  . This rich and opulent blend of Cabernet Sauv...
# 83416    Italy  100% Cabernet Sauvignon, this opens with aroma...
# ...        ...                                                ...
# 98934   France  Zind-Humbrecht owns some great Grand Cru viney...
# 70889    Italy  Zisola is a Nero d'Avola that is aged 10 month...
# 80210    Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487    Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953    Italy  Zorzettig's precious Picolit dessert wine deli...
#
#                                         designation  points  price  \
# id
# 115413                                      Rubiolo      88   23.0
# ...

# %%
reviews.loc[reviews.price.notnull()] #operador logico de pandas el cual muestra los valores que no son nulos dentro del conjunto de datos (el archivo csv)
# Out:
#         country                                        description  \
# id
# 94355   Austria  "Chremisa," the ancient name of Krems, is comm...
# 126883       US  $10 for this very drinkable Cab? That's crazy....
# 119493       US  $14 is a pretty good price for a Chardonnay th...
# 126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 119752    Spain  ). Light and lemony on the nose. The palate ha...
# ...         ...                                                ...
# 129643       US  Zocker flies under the radar with this Austria...
# 80210     Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487     Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 18824        US  Zucca has made a fragrant and floral Sangioves...
# 88999   Austria  Zweigelt can do easy-drinking styles but in th...
#
#                           designation  points  price          province  \
# id
# 94355   Edition Chremisa Sandgrube 13      85   24.0  Niederösterreich
# ...

# %% [markdown]
# #### **02.2.5. Asignacion de datos**
# Creacion de datos dentro del conjunto de datos.

# %%
reviews['critic'] = 'everyone' #se puede asignar valores dentro del conjunto de datos tambien
reviews['critic']
# Out:
# id
# 94355     everyone
# 126883    everyone
# 119493    everyone
# 126909    everyone
# 119752    everyone
#             ...
# 80210     everyone
# 76487     everyone
# 86953     everyone
# 18824     everyone
# 88999     everyone
# Name: critic, Length: 119988, dtype: object

# %% [markdown]
# ## **02.3. Funciones resumen y Mapas**

# %% [markdown]
# ### **02.3.1. Funciones resumen**
# Sirve para representar los datos de una forma diferente por ende mas util

# %% [markdown]
#  - `describe()`: Es un resumen de la columna que se le ha pasado como argumento a este metodo, depende el tipo de variable que este almacenada en la columna cambia la representacion de los datos.

# %%
reviews.points.describe() #variable tipo float64
# Out:
# count    119988.000000
# mean         88.442236
# std           3.092915
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.taster_name.describe() #variable tipo objeto
# Out:
# count          95071
# unique            19
# top       Roger Voss
# freq           23560
# Name: taster_name, dtype: object

# %% [markdown]
# - `mean()`: Devuelve la media de los valores almacenados en la columna que se indique.

# %%
reviews.points.mean()
# Out:
# np.float64(88.44223589025569)

# %% [markdown]
# - `median()`: devuelve la media de los valores que esten en el eje que se pida.

# %%
reviews.points.median()
# Out:
# 88.0

# %% [markdown]
# - `unique()`: Devuelve los valores unicos que estan en la columna o fila que se pide.

# %%
reviews.taster_name.unique()
# Out:
# array(['Roger Voss', 'Virginie Boone', nan, 'Michael Schachner',
#        'Anna Lee C. Iijima', 'Paul Gregutt', 'Sean P. Sullivan',
#        'Kerin O’Keefe', 'Anne Krebiehl\xa0MW', 'Lauren Buzzeo',
#        'Joe Czerwinski', 'Alexander Peartree', 'Matt Kettmann',
#        'Jim Gordon', 'Susan Kostrzewa', 'Mike DeSimone', 'Jeff Jenssen',
#        'Christina Pickard', 'Carrie Dykes', 'Fiona Adams'], dtype=object)

# %% [markdown]
#  - `value_counts()`: Cantidad de veces que aparece un valor de una variable determinada.

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss            23560
# Michael Schachner     14046
# Kerin O’Keefe          9697
# Paul Gregutt           8868
# Virginie Boone         8708
# Matt Kettmann          5730
# Joe Czerwinski         4766
# Sean P. Sullivan       4461
# Anna Lee C. Iijima     4017
# Jim Gordon             3766
# Anne Krebiehl MW       3290
# Lauren Buzzeo          1700
# Susan Kostrzewa        1023
# Mike DeSimone           461
# Jeff Jenssen            436
# Alexander Peartree      383
# Carrie Dykes            129
# Fiona Adams              24
# Christina Pickard         6
# Name: count, dtype: int64

# %% [markdown]
# ### **02.3.2. Mapas**
# El término «mapa», tomado de las matemáticas, se refiere a una función que toma un conjunto de valores y los «asigna» a otro conjunto de valores. En la ciencia de datos, a menudo necesitamos crear nuevas representaciones a partir de datos existentes, o transformar los datos del formato en el que se encuentran ahora al formato que queremos que tengan más adelante. Los mapas son los que se encargan de esta tarea, ¡lo que los convierte en elementos extremadamente importantes para llevar a cabo tu trabajo!

# %% [markdown]
# - `(lambda p :)`-> Define una funcion rapida e innominada la cual recibe como parametro de entrada p el cual es un valor individual o un elemento de la serie.
#
# - `(p - review_points_mean)`-> Le resta dicho valor p a la variable `review_points_mean`.

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# id
# 94355    -3.442236
# 126883   -1.442236
# 119493   -2.442236
# 126909   -2.442236
# 119752   -1.442236
#             ...
# 80210     1.557764
# 76487    -0.442236
# 86953     1.557764
# 18824    -1.442236
# 88999     1.557764
# Name: points, Length: 119988, dtype: float64

# %% [markdown]
# - Devuelve una tabla la cual tien alterada los valores de la columna "points".
# - Se puede cambiar el valor de `axis` para que en vez de ir por columnas vaya por filas (`axis=index`).
# - `apply` conmuta cambios en la tabla segun los valores que se le pasen.

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#         country                                        description  \
# id
# 94355   Austria  "Chremisa," the ancient name of Krems, is comm...
# 126883       US  $10 for this very drinkable Cab? That's crazy....
# 119493       US  $14 is a pretty good price for a Chardonnay th...
# 126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 119752    Spain  ). Light and lemony on the nose. The palate ha...
# ...         ...                                                ...
# 80210     Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487     Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953     Italy  Zorzettig's precious Picolit dessert wine deli...
# 18824        US  Zucca has made a fragrant and floral Sangioves...
# 88999   Austria  Zweigelt can do easy-drinking styles but in th...
#
#                           designation    points  price            province  \
# id
# 94355   Edition Chremisa Sandgrube 13 -3.442236   24.0    Niederösterreich
# ...

# %% [markdown]
# - Realiza lo mismo que en anterior apartado pero con las operaciones integradas en Pandas, por lo tanto estas contienen unos metodos mas optimizados y por ende son mas rapidos y eficientes.

# %%
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# id
# 94355    -3.442236
# 126883   -1.442236
# 119493   -2.442236
# 126909   -2.442236
# 119752   -1.442236
#             ...
# 80210     1.557764
# 76487    -0.442236
# 86953     1.557764
# 18824    -1.442236
# 88999     1.557764
# Name: points, Length: 119988, dtype: float64

# %% [markdown]
# - En este código estamos realizando una operación entre muchos valores en el lado izquierdo (todo lo que hay en la serie) y un único valor en el lado derecho (el valor medio). Pandas analiza esta expresión y deduce que lo que queremos hacer es restar ese valor medio de cada valor del conjunto de datos.
#
# - Pandas también sabrá qué hacer si realizamos estas operaciones entre Series de la misma longitud. Por ejemplo, una forma sencilla de combinar la información de país y región en el conjunto de datos sería hacer lo siguiente.

# %%
reviews.country + " - " + reviews.region_1
# Out:
# id
# 94355                                    NaN
# 126883                      US - North Coast
# 119493                       US - California
# 126909              Spain - Ribera del Duero
# 119752                   Spain - Rías Baixas
#                          ...
# 80210                         Italy - Barolo
# 76487     Italy - Amarone della Valpolicella
# 86953     Italy - Colli Orientali del Friuli
# 18824                     US - Amador County
# 88999                                    NaN
# Length: 119988, dtype: object

# %% [markdown]
# Estos operadores son más rápidos que map() o apply(), ya que utilizan las optimizaciones integradas en pandas. Todos los operadores estándar de Python (>, <, ==, etc.) funcionan de esta manera.
#
# Sin embargo, no son tan flexibles como map() o apply(), que permiten realizar operaciones más avanzadas, como aplicar lógica condicional, algo que no se puede hacer solo con la suma y la resta.

# %% [markdown]
# ## **02.4. Agrupaciones y Filtrado**

# %% [markdown]
# ### 02.4.1. Analisis por grupos

# %% [markdown]
# - `groupby()`: funcion la cual agrupa los valores almacenados en las columnas que se le pasen como argumento a esta funcion.
# - `count()`: funcion del grupo de funciones *groupby()* la cual permite contar los valores agrupados.

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       689
# 82      1814
# 83      2963
# 84      6225
# 85      9067
# 86     11526
# 87     15279
# 88     15291
# 89     11147
# 90     13893
# 91     10559
# 92      8951
# 93      6170
# 94      3625
# 95      1514
# 96       521
# 97       228
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %% [markdown]
# - `size()`: en este contexto hace lo mismo que *count()* pero es mas escueto en algunos aspectos.

# %%
reviews.groupby('points').size()
# Out:
# points
# 80       397
# 81       689
# 82      1814
# 83      2963
# 84      6225
# 85      9067
# 86     11526
# 87     15279
# 88     15291
# 89     11147
# 90     13893
# 91     10559
# 92      8951
# 93      6170
# 94      3625
# 95      1514
# 96       521
# 97       228
# 98        77
# 99        33
# 100       19
# dtype: int64

# %% [markdown]
# - `min()`: funcion del grupo de funciones de *groupby()* la cual sirve para devolver los minimos dentro de un grupo.
# - `reviews.groupby('points').price.min()`: Se entiende como agrupar por el valor de los puntos, el valor de la columna de precios, y de esa columna de precios devuelve el minimo valor que se asocie a la columna de puntos.
#
# >Interpretacion de la IA para mas ayuda al entendimiento de esta parte:
# >* **`reviews.groupby('points')`**: Separa la estructura de datos en grupos según los valores únicos de la columna **`points`**.
# >* **`.price`**: Selecciona únicamente la columna de precios para cada uno de los grupos formados.
# >* **`.min()`**: Calcula el valor más bajo dentro de la columna de precios para cada grupo.
# >
# > El resultado es una Serie de Pandas donde el índice son los puntajes de la columna **`points`** y sus valores asociados son los precios mínimos encontrados para cada puntaje.

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %% [markdown]
# Podemos considerar que cada grupo que generamos es una sección de nuestro DataFrame que contiene únicamente datos con valores coincidentes. Podemos acceder directamente a este DataFrame mediante el método *apply()*, y a continuación podemos manipular los datos como mejor nos parezca. Por ejemplo, esta es una forma de seleccionar el nombre del primer vino reseñado de cada bodega del conjunto de datos:

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# /tmp/ipykernel_9243/506966275.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                   10 Knots 2006 Beachcomber White (Paso Robles)
# 100 Percent Wine       100 Percent Wine 2014 All Profits to Charity S...
# 1000 Stories           1000 Stories 2014 Bourbon Barrel Aged Batch No...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# ...

# %% [markdown]
# Se puede tener un control mas precioso, tambien se puede agrupar por mas de una columna, un ejemplo de esto esta en el siguiente bloque de codigo.

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
# /tmp/ipykernel_9243/1865732994.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Armenia   Armenia             Armenia
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
# ...

# %% [markdown]
# - `agg()`: pertenece al grupo de funciones de *groupby()* esta en especifico permite ejecutar diferentes funciones en el DataFrame de forma simultanea.

# %%
reviews.groupby(['country']).price.agg([len, "min", "max"])
# Out:
#                           len   min     max
# country
# Argentina                3544   4.0   230.0
# Armenia                     2  14.0    15.0
# Australia                2197   5.0   850.0
# Austria                  3034   7.0  1100.0
# Bosnia and Herzegovina      2  12.0    13.0
# Brazil                     49  10.0    60.0
# Bulgaria                  132   8.0   100.0
# Canada                    226  12.0   120.0
# Chile                    4184   5.0   400.0
# China                       1  18.0    18.0
# Croatia                    70  12.0    65.0
# Cyprus                     10  11.0    21.0
# Czech Republic             11  15.0    45.0
# Egypt                       1   NaN     NaN
# England                    63  25.0    95.0
# France                  20353   5.0  3300.0
# Georgia                    76   9.0    40.0
# Germany                  1992   5.0   775.0
# Greece                    432   8.0    79.0
# Hungary                   129  10.0   764.0
# ...

# %% [markdown]
# ### **02.4.2. Indices multiples**

# %% [markdown]
# Los indices multiples se diferencian de los indices normales porque estos tienen varios niveles.

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3038
#           Other              506
# Armenia   Armenia              2
# Australia Australia Other    231
#           New South Wales     82
# ...                          ...
# Uruguay   Juanico             11
#           Montevideo          10
#           Progreso            11
#           San Jose             3
#           Uruguay             23
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# Los índices múltiples cuentan con varios métodos para gestionar su estructura por niveles, que no existen en los índices de un solo nivel. Además, requieren dos niveles de etiquetas para recuperar un valor. Gestionar los resultados de los índices múltiples suele ser una «trampa» habitual para los usuarios que se inician en pandas.
#
# Los casos de uso de un índice múltiple se detallan junto con las instrucciones para utilizarlos en la sección «MultiIndex / Advanced Selection» de la documentación de pandas.
#
# Sin embargo, en general, el método de índice múltiple que utilizarás con más frecuencia es el que sirve para volver a convertirlo en un índice normal, el método `reset_index()`.

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3038
# 1    Argentina             Other   506
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   231
# 4    Australia   New South Wales    82
# ..         ...               ...   ...
# 420    Uruguay           Juanico    11
# 421    Uruguay        Montevideo    10
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    23
#
# [425 rows x 3 columns]

# %% [markdown]
# ### **02.4.3. Filtrado**

# %% [markdown]
# Usando la tabla que se genero en el indice multiple anterior, como se puede comprobar los valores de dicha tabla no estaban ordenados, por lo tanto se pued usar *sort_values()* para realizar esta ordenacion.
#
# - `sort_values()`: funcion del grupo de funciones *groupby()* la cual permite ordenar la tabla por un valor que se le adjunta como clave del orden.

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#           country           province    len
# 386        Turkey  Elazığ-Diyarbakir      1
# 389        Turkey        Urla-Thrace      1
# 395            US             Hawaii      1
# 357  South Africa    Piekenierskloof      1
# 354  South Africa         Paardeberg      1
# ..            ...                ...    ...
# 409            US             Oregon   4929
# 227         Italy            Tuscany   5391
# 118        France           Bordeaux   5556
# 415            US         Washington   7965
# 392            US         California  33656
#
# [425 rows x 3 columns]

# %% [markdown]
# La función *sort_values()* ordena por defecto de forma ascendente, es decir, los valores más bajos aparecen primero. Sin embargo, la mayoría de las veces queremos una ordenación descendente, en la que los números más altos aparezcan primero.

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country          province    len
# 392      US        California  33656
# 415      US        Washington   7965
# 118  France          Bordeaux   5556
# 227   Italy           Tuscany   5391
# 409      US            Oregon   4929
# ..      ...               ...    ...
# 389  Turkey       Urla-Thrace      1
# 48   Canada      Canada Other      1
# 40   Brazil  Serra do Sudeste      1
# 395      US            Hawaii      1
# 399      US          Kentucky      1
#
# [425 rows x 3 columns]

# %% [markdown]
# Se puede filtrar mas de una columna a la vez.

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   506
# 0    Argentina  Mendoza Province  3038
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    36
# 4    Australia   New South Wales    82
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    10
# 420    Uruguay           Juanico    11
# 422    Uruguay          Progreso    11
# 424    Uruguay           Uruguay    23
# 419    Uruguay         Canelones    35
#
# [425 rows x 3 columns]

# %% [markdown]
# ## **02.5. Tipos de datos y valores vacios o perdidos**

# %% [markdown]
# ### **02.5.1. Dtype**
#
# - `database.column.dtype`: Devuelve el tipo de la columna.

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - `dtypes`: Tambien puede devolver el tipo de todas las columnas dentro del DataFrame.

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dupe?                    float64
# dtype: object

# %% [markdown]
# - `astype()`: Convertir una columna a otro tipo.
#
# Las cadenas de texto por norma general pandas las interpreta como tipo *object*, y de base utiliza *int64* y *float64* como tipo de datos para enteros y con decimales.

# %%
reviews.points.astype('float64')
# Out:
# id
# 94355     85.0
# 126883    87.0
# 119493    86.0
# 126909    86.0
# 119752    87.0
#           ...
# 80210     90.0
# 76487     88.0
# 86953     90.0
# 18824     87.0
# 88999     90.0
# Name: points, Length: 119988, dtype: float64

# %% [markdown]
# - `database.index.dtype`: Comprueba el tipo del indice de los DataFrames o Series.

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### **02.5.2. Datos perdidos**
# Puede haber valores que no existen o se han perdido en la lectura de la base de datos los cuales se interpretan como *NaN* que significa *Not a Number* por lo general siempre los NaN se les atribuye el valor de *float64* como base.
#
# - `pd.isnull()`: comprueba si hay valores nulos en el DataFrame.
# - `pd.isnotnull()`: es lo contrario del anterior metodo, comprueba los valores no nulos del DataFrame.

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# id
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 11150      NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 46352      NaN  A dark color and rich, jammy, baked aromas of ...
# 105167     NaN  A lively whiff of white blossom, Muscat grapes...
# 85821      NaN  A neutral nose leads onto an apple-fresh palat...
# 54222      NaN  Almost caramel in color, this wine offers arom...
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 66524      NaN  Amber to the eye, this wine features an entici...
# 36112      NaN  An interesting blend of indigenous Bulgarian a...
# 105715     NaN  Aromas of blackberry, strawberry and chocolate...
# 49510      NaN  Aromas of cherry, blueberry and rose petal pre...
# 113520     NaN  Aromas of crushed stone and graphite lead toas...
# 90146      NaN  Aromas of cut grass, lemongrass and honeysuckl...
# ...

# %% [markdown]
# > Lo mismo pero se puede sumar de esta forma para obtener cuantos valores son nulos, para ello utilizar *sum()*

# %%
reviews.price.isnull()
# Out:
# id
# 94355     False
# 126883    False
# 119493    False
# 126909    False
# 119752    False
#           ...
# 80210     False
# 76487     False
# 86953      True
# 18824     False
# 88999     False
# Name: price, Length: 119988, dtype: bool

# %% [markdown]
# - `fillna()`: Se utiliza para rellenar las entradas del DataFrame cuyo valor es NaN con los otros valores que se le pasen a este metodo.

# %%
reviews.region_2.fillna("Unknown")
# Out:
# id
# 94355              Unknown
# 126883         North Coast
# 119493    California Other
# 126909             Unknown
# 119752             Unknown
#                 ...
# 80210              Unknown
# 76487              Unknown
# 86953              Unknown
# 18824     Sierra Foothills
# 88999              Unknown
# Name: region_2, Length: 119988, dtype: object

# %% [markdown]
# - `replace()`: cambia un valor dentro del DataFrame, este o no este NaN, por otro valor que se le introduzca al metodo.

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# id
# 94355      @vossroger
# 126883        @vboone
# 119493            NaN
# 126909    @wineschach
# 119752    @wineschach
#              ...
# 80210             NaN
# 76487             NaN
# 86953             NaN
# 18824         @vboone
# 88999     @AnneInVino
# Name: taster_twitter_handle, Length: 119988, dtype: object

# %% [markdown]
# ## **02.6. Renombrar y Combinar**

# %% [markdown]
# ### **02.6.1. Renombrar**
#
# - `rename()`: permite cambiar el nombre del indice y de las columnas.

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#         country                                        description  \
# id
# 94355   Austria  "Chremisa," the ancient name of Krems, is comm...
# 126883       US  $10 for this very drinkable Cab? That's crazy....
# 119493       US  $14 is a pretty good price for a Chardonnay th...
# 126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 119752    Spain  ). Light and lemony on the nose. The palate ha...
# ...         ...                                                ...
# 80210     Italy  Zonchera is Ceretto's more affordable base Bar...
# 76487     Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 86953     Italy  Zorzettig's precious Picolit dessert wine deli...
# 18824        US  Zucca has made a fragrant and floral Sangioves...
# 88999   Austria  Zweigelt can do easy-drinking styles but in th...
#
#                           designation  score  price            province  \
# id
# 94355   Edition Chremisa Sandgrube 13     85   24.0    Niederösterreich
# ...

# %%
reviews.rename(columns={'region_1': 'region', 'region_2': 'locale'})
# Out:
#             id  country                                        description  \
# 0        94355  Austria  "Chremisa," the ancient name of Krems, is comm...
# 1       126883       US  $10 for this very drinkable Cab? That's crazy....
# 2       119493       US  $14 is a pretty good price for a Chardonnay th...
# 3       126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 4       119752    Spain  ). Light and lemony on the nose. The palate ha...
# ...        ...      ...                                                ...
# 119983   80210    Italy  Zonchera is Ceretto's more affordable base Bar...
# 119984   76487    Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 119985   86953    Italy  Zorzettig's precious Picolit dessert wine deli...
# 119986   18824       US  Zucca has made a fragrant and floral Sangioves...
# 119987   88999  Austria  Zweigelt can do easy-drinking styles but in th...
#
# ...

# %% [markdown]
# > Se puede renombrar por el valor del parametro de la columna o del indice, normalmente se renombrara con diccionarios de Python ya que es mas conveniente.

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                  id  country  \
# firstEntry    94355  Austria
# secondEntry  126883       US
# 2            119493       US
# 3            126909    Spain
# 4            119752    Spain
# ...             ...      ...
# 119983        80210    Italy
# 119984        76487    Italy
# 119985        86953    Italy
# 119986        18824       US
# 119987        88999  Austria
#
#                                                    description  \
# firstEntry   "Chremisa," the ancient name of Krems, is comm...
# secondEntry  $10 for this very drinkable Cab? That's crazy....
# 2            $14 is a pretty good price for a Chardonnay th...
# 3            ). Earth, cola and leather aromas are good, ho...
# 4            ). Light and lemony on the nose. The palate ha...
# ...                                                        ...
# 119983       Zonchera is Ceretto's more affordable base Bar...
# 119984       Zonin's 2006 Amarone opens with very ripe arom...
# ...

# %% [markdown]
# - `set_index()`: permite renombrar el indice de manera mas sencilla que el anterior metodo.
# - `rename_axis()`: permite permite renombrar por eje, por lo tanto permite renombrar el nombre de las filas y de las columnas, tener en cuenta que por nombre no me refiero a el nombre de las columnas individuales si no al nombre de las columnas como grupo y viceversa.

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields      id  country                                        description  \
# wines
# 0        94355  Austria  "Chremisa," the ancient name of Krems, is comm...
# 1       126883       US  $10 for this very drinkable Cab? That's crazy....
# 2       119493       US  $14 is a pretty good price for a Chardonnay th...
# 3       126909    Spain  ). Earth, cola and leather aromas are good, ho...
# 4       119752    Spain  ). Light and lemony on the nose. The palate ha...
# ...        ...      ...                                                ...
# 119983   80210    Italy  Zonchera is Ceretto's more affordable base Bar...
# 119984   76487    Italy  Zonin's 2006 Amarone opens with very ripe arom...
# 119985   86953    Italy  Zorzettig's precious Picolit dessert wine deli...
# 119986   18824       US  Zucca has made a fragrant and floral Sangioves...
# 119987   88999  Austria  Zweigelt can do easy-drinking styles but in th...
#
# ...

# %% [markdown]
# ### **02.6.2. Combinar**
# Hay tres metodos para unir DataFrames o Series con Pandas estos son *concat()*, *join()* y *merge()*, casi todo lo que hace *merge()* se puede hacer con un simple *join()*, por lo tanto se prefiere simplificar el uso a las dos primeras funciones que he nombrado antes.
#
# - `concat()`: dadas lista de elementos se encarga de juntarlos directamente.
# > Nota este es el metodo mas facil para unir DataFrames o Series.

# %%
canadian_youtube = pd.read_csv("./archivosDeDatos/CAvideos.csv")
british_youtube = pd.read_csv("./archivosDeDatos/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %% [markdown]
# `join()`: permite combinar distintos objetos de DataFrames los cuales tienen un indice en comun.
#
# >Los parámetros *lsuffix* y *rsuffix* son necesarios en este caso porque los datos tienen los mismos nombres de columna tanto en el conjunto de datos británico como en el canadiense. Si no fuera así (por ejemplo, porque los hubiéramos renombrado previamente), no los necesitaríamos.

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
# ...                                                                       ...
# HOW2: How to Solve a Mystery                       18.14.06       sGolxsMSGfQ
# Eli Lik Lik Episode 13 Partie 01                   18.14.06       8HNuRNi8t70
# KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 20... 18.14.06       GWlKEM3m2EE
# Trump Advisor Grovels To Trudeau                   18.14.06       lbMKLzQ4cNQ
# ...

# %% [markdown]
# ## 02.7. **Ejercicios interesentes echos con este modulo**

# %% [markdown]
# ### 02.7.1. **Usando loc**

# %%
# Fill in the line below: What is the highest average score received by PC games,
# for any genre?
high_score = max(ign_data.loc['PC', :])

# Fill in the line below: On the Playstation Vita platform, which genre has the 
# lowest average score? Please provide the name of the column, and put your answer 
# in single quotes (e.g., 'Action', 'Adventure', 'Fighting', etc.)
worst_genre = ign_data.loc['PlayStation Vita',:].idxmin()

# Check your answers
step_2.check()

# %%
# Fill in the line below: Which candy was more popular with survey respondents:
# '3 Musketeers' or 'Almond Joy'?  (Please enclose your answer in single quotes.)
more_popular = candy_data.loc[candy_data.loc[:5, 'winpercent'].idxmax(), 'competitorname']

# Fill in the line below: Which candy has higher sugar content: 'Air Heads'
# or 'Baby Ruth'? (Please enclose your answer in single quotes.)
more_sugar = candy_data.loc[candy_data.loc[:5, 'sugarpercent'].idxmax(), 'competitorname']

# Check your answers
step_2.check()
