# %% [markdown]
# # **04. Visualizacion de datos**

# %% [markdown]
# ## **04.1. Uso de la libreria Seaborn**

# %% [markdown]
# ### **04.1.1. Configuracion del entorno**

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## **04.2. Graficos de lineas**

# %% [markdown]
# ### **04.2.1. Carga de los datos**

# %% [markdown]
# - `read_csv()`: permite leer un archivo para interpretarlo con pandas.

# %%
# Path of the file to read
spotify_filepath = "./archivosDeDatos/spotify.csv"

# Read the file into a variable spotify_data
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

# %% [markdown]
# ### **04.2.2. Examinar los datos**

# %% [markdown]
# - `head()`: permite ver las cinco primeras filas del archivo csv.
# > NaN significa Not a Number (No es un numero).

# %%
# Print the first 5 rows of the data
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# - `tail()`: imprime las ultimas 5 filas de la base de datos.

# %%
# Print the last five rows of the data
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# ### **04.2.3. Representacion de los datos**

# %% [markdown]
# - `sns.lineplot()`: basicamente se comunica con seaborn para decirle que cree un grafico de lineas.
# > `data=spotify_data`: indica que datos se van a utilizar en el grafico.

# %%
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# > configuracion mas profunda del grafico de lineas.

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song
sns.lineplot(data=spotify_data)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %% [markdown]
# ### **04.2.4. Representar gráficamente un subconjunto de los datos**

# %% [markdown]
# - `list()`: lista los valores del conjunto de datos que se le pase.
# > `db.columns`: muestra solo las columnas.

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# > configuracion con los datos antes sacados de un grafico de lineas mas completo.

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## **04.3. Gráficos de barras y mapas de calor**

# %% [markdown]
# ### **04.3.1. Carga de datos**

# %%
# Path of the file to read
flight_filepath = "./archivosDeDatos/flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %% [markdown]
# ### **04.3.2. Examinar los datos**

# %% [markdown]
# - `shape`: permite ver el tamaño total del contenido del archivo csv.

# %%
flight_data.shape
# Out:
# (12, 14)

# %%
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %% [markdown]
# ### **04.3.3. Grafico de barras**

# %% [markdown]
# Los comandos para personalizar el texto (título y etiqueta del eje vertical) y el tamaño de la figura ya los conocemos del tutorial anterior. El código que crea el gráfico de barras es nuevo:
#
# ```python
# # Gráfico de barras que muestra el retraso medio de llegada de los vuelos de Spirit Airlines por mes
# sns.barplot(x=flight_data.index, y=flight_data[“NK”])
# ```
#
# Consta de tres componentes principales:
#
# - `sns.barplot`: indica al cuaderno que queremos crear un gráfico de barras.
#   - Recuerda que *''sns''* hace referencia al paquete seaborn, y todos los comandos que utilices para crear gráficos en este curso comenzarán con este prefijo.
# - `x=flight_data.index`: determina qué se utilizará en el eje horizontal. En este caso, hemos seleccionado la columna que indexa las filas (en este caso, la columna que contiene los meses).
# - `y=flight_data[“NK”]`: establece la columna de los datos que se utilizará para determinar la altura de cada barra. En este caso, seleccionamos la columna *''NK'"*.
#
# > **Nota importante**: Debes seleccionar la columna de indexación con flight_data.index, y no es posible utilizar *flight_data[“Month”]* (lo cual generará un error). Esto se debe a que, al cargar el conjunto de datos, se utilizó la columna *''Month''* para indexar las filas. Siempre debemos utilizar esta notación especial para seleccionar la columna de indexación.

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=flight_data.index, y=flight_data['NK'])

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# ### **04.3.4. Mapas de calor**

# %% [markdown]
# El código correspondiente para crear el mapa de calor es el siguiente:
#
# ```python
# # Mapa de calor que muestra el retraso medio de llegada de cada aerolínea por mes
# sns.heatmap(data=flight_data, annot=True)
# ```
# Este código tiene tres componentes principales:
#
# - `sns.heatmap`: indica al cuaderno que queremos crear un mapa de calor.
# - `data=flight_data`: indica al cuaderno que utilice todas las entradas de *flight_data* para crear el mapa de calor.
# - `annot=True`: garantiza que los valores de cada celda aparezcan en el gráfico. (¡Si se omite, se eliminan los números de cada una de las celdas!)
#
# ¿Qué patrones puedes detectar en la tabla? Por ejemplo, si te fijas bien, los meses hacia finales de año (especialmente los meses 9 a 11) aparecen relativamente oscuros para todas las aerolíneas. ¡Esto sugiere que las aerolíneas son mejores (de media) a la hora de cumplir con los horarios durante estos meses!

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 47.7222222222222, 'Airline')
